# %% [markdown]
# <a href="https://colab.research.google.com/github/Kashishkewat/python_practice/blob/main/day8_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **OPP Basics in python**

# %% [markdown]
# OOP is a way of programming that organizes code using classes and objects.

# %% [markdown]
# **1. Class and Object**
# ➤ Class
#
# A class is a blueprint for creating objects.
#
# ➤ Object
#
# An object is an instance of a class.
#
# class Student:

# %%
class Student:
    pass

s1 = Student()   # object

# %% [markdown]
# **2. __init__() Constructor**
#
# Used to initialize object data

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Kashish", 21)
print(s1.name)

# %% [markdown]
# **3. self Keyword**

# %%
self.name = name

# %% [markdown]
# **4. Methods (Functions inside Class)**

# %%
class Student:
    def greet(self):
        print("Hello Student")

s1 = Student()
s1.greet()

# %% [markdown]
# **mini** **project**
#
# ---

# %%
class BankAccount:
    def __init__(self, name, account_no, balance=0):
        self.name = name
        self.account_no = account_no
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print("Deposited:", amount)

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print("Withdrawn:", amount)
        else:
            print("Insufficient balance")

    def display(self):
        print("\nAccount Holder:", self.name)
        print("Account Number:", self.account_no)
        print("Balance:", self.balance)
