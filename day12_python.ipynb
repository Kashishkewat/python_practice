# %% [markdown]
# <a href="https://colab.research.google.com/github/Kashishkewat/python_practice/blob/main/day12_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Encapsulation**
#
# Encapsulation means wrapping data (variables) and methods into a single unit (class) and restricting direct access to data.

# %%
#Example of Encapsulation
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance   # private variable

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def show_balance(self):
        print("Balance:", self.__balance)

# %% [markdown]
# # **Abstraction**
#
# ---

# %% [markdown]
# Abstraction means hiding implementation details and showing only essential features.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass
class Car(Vehicle):
    def start(self):
        print("Car starts with key")

class Bike(Vehicle):
    def start(self):
        print("Bike starts with button")
c = Car()
b = Bike()

c.start()
b.start()
# Out:
# Car starts with key
# Bike starts with button

# %% [markdown]
# **Mini Project**
#
# ---

# %%
# Abstract Base Class: Vehicle
from abc import ABC, abstractmethod

class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass
 #Concrete Class: Car
class Car(Vehicle):

    def start(self):
        print("Car starts with key")

    def stop(self):
        print("Car stops using brakes")

    def fuel_type(self):
        print("Fuel type: Petrol / Diesel")
#Concrete Class: Bike
class Bike(Vehicle):

    def start(self):
        print("Bike starts with self-start or kick")

    def stop(self):
        print("Bike stops using disc brakes")

    def fuel_type(self):
        print("Fuel type: Petrol")

# Concrete Class: ElectricCar
class ElectricCar(Vehicle):

    def start(self):
        print("Electric car starts silently")

    def stop(self):
        print("Electric car uses regenerative braking")

    def fuel_type(self):
        print("Fuel type: Electricity")
# Polymorphism in Action
vehicles = [Car(), Bike(), ElectricCar()]

for v in vehicles:
    v.start()
    v.fuel_type()
    v.stop()
    print("------")
# Out:
# Car starts with key
# Fuel type: Petrol / Diesel
# Car stops using brakes
# ------
# Bike starts with self-start or kick
# Fuel type: Petrol
# Bike stops using disc brakes
# ------
# Electric car starts silently
# Fuel type: Electricity
# Electric car uses regenerative braking
# ------
