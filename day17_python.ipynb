# %% [markdown]
# <a href="https://colab.research.google.com/github/Kashishkewat/python_practice/blob/main/day17_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Seaborn**

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins=sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins["species"].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins["island"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
sns.scatterplot(data=penguins,x='flipper_length_mm',y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins,x='flipper_length_mm',y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# **The ways of styling themes are as follows:**
# 1. white
# 2. dark
# 3. whitegrid
# 4. darkgrid
# 5. ticks

# %%
sns.set_style("white")
sns.set_context("notebook")#paper ,notebook,talk,poster
sns.scatterplot(data=penguins,x='flipper_length_mm',y="body_mass_g",hue="sex",palette="Set2")
sns.despine()

# %%
sns.scatterplot(data=penguins,x="species",y="body_mass_g",hue='island',style="sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(data=penguins,x="species",y="body_mass_g",hue="island",dodge=True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#swarm plot
sns.set_context("talk")
sns.swarmplot(data=penguins,x="species",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#histogram

sns.histplot(data=penguins,x="body_mass_g",hue="sex",multiple="stack")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
#regression plot
sns.regplot(data=penguins,x="body_mass_g",y="flipper_length_mm",color='green')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
#line plot
sns.set_style("whitegrid")
sns.lineplot(data=penguins,x="body_mass_g",y="flipper_length_mm",hue="sex")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
#jointplot
sns.jointplot(data=penguins,x="body_mass_g",y="flipper_length_mm",hue="species",kind="scatter")
#

# %%
#bar plot
sns.barplot(data=penguins,x='species',y="body_mass_g",hue="sex",palette={"yellow","green"},estimator=np.std)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#count plot
sns.countplot(data=penguins,x="species",hue="sex",palette='Set1')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
#box plot
sns.boxplot(data=penguins,x="species",y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# violin plot
sns.violinplot(data=penguins,x="species",y="body_mass_g",hue="sex",palette="Set1")
sns.swarmplot(data=penguins,x="species",y="body_mass_g",color="black")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# KDE-> for estimmating the probability density function of continuous or non parametric data
# or in simple terms: a smooth curve that shows the distrabution of data - like a smoothed -out version .It hepls you see where the data is concentrated(peaks) and how it spreads.

# %%
sns.kdeplot(data=penguins,x="body_mass_g",hue="species",palette="pastel",fill="True")
sns.despine()

# %% [markdown]
# **heatmap: a 2d color_coded matrix that shows relationshils or patterns between two variables.**
#
# **It's commonly used to:
# -:show correlation between features**
#
# **-:visualize confusion matrics-> will see in the later stages.**
#
# **-:highlight missing data->sns.heatmap(df.isnull())**

# %%
columns=['bill_length_mm',"bill_depth_mm","flipper_length_mm","body_mass_g"]
sns.heatmap(data=penguins[columns].corr(),annot=True,cmap="Blues",vmin=-0.2,linewidth=2)
# Out:
# <Axes: >

# %%
#rug plot:
sns.rugplot(data=penguins,x="body_mass_g",y="species",palette="Set1",height=0.3)
# Out:
# /tmp/ipython-input-3572416048.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.rugplot(data=penguins,x="body_mass_g",y="species",palette="Set1",height=0.3)
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %%
# pair plot:
sns.pairplot(data=penguins[columns],palette="Set1",diag_kind="kde")
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
#pair grid-> subplot grid for plotting pairwise relationships in a dataset.
plot_columns = columns + ['sex']
g=sns.PairGrid(data=penguins[plot_columns],hue="sex",palette="Set1")
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.histplot)

# %% [markdown]
# # **Mini Project Python**

# %%
#Bar Chart
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
subjects = ['Math', 'Science', 'English', 'Computer']
marks = [85, 90, 78, 92]

sns.barplot(x=subjects, y=marks)
plt.title("Bar Chart - Student Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
# Line Graph
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
days = [1, 2, 3, 4, 5]
sales = [200, 250, 300, 280, 350]

sns.lineplot(x=days, y=sales)
plt.title("Line Graph - Sales Over Days")
plt.xlabel("Days")
plt.ylabel("Sales")
plt.show()

# %%
#Pie Chart
import seaborn as sns
import matplotlib.pyplot as plt

# Seaborn style
sns.set_style("whitegrid")

labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 25, 20, 15]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart - Programming Language Usage")
plt.axis('equal')  # Makes circle perfect
plt.show()
